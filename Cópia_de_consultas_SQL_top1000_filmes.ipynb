# %% [markdown]
# # **TRABALHO INDIVIDUAL: consultas SQL em base de dados sobre filmes**

# %% [markdown]
# > ###### ATENÇÃO!
# > ###### - Faça o upload do arquivo CSV no Colab;
# > ###### - Ao lado, clique nos ícones de pasta e folha (com seta para cima) para começar a transferência.
# > ###### - Clique no botão play ▶ em cada célula para executar uma após a outra.

# %% [markdown]
# > ### PRÉ-PROCESSAMENTO DA BASE DE DADOS

# %%
# Preparação do ambiente
# Use a biblioteca Pandas para carregar o CSV e o SQLite para consultas SQL.
import pandas as pd
import sqlite3

# %%
# Carrega a planilha em formato CSV e salva a base de dados com o nome "filmes"
filmes = pd.read_csv('/content/Highest Holywood Grossing Movies.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1102/1767461899.py in <cell line: 0>()
#       1 # Carrega a planilha em formato CSV e salva a base de dados com o nome "filmes"
# ----> 2 filmes = pd.read_csv('/content/Highest Holywood Grossing Movies.csv')
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     871         if ioargs.encoding and "b" not in ioargs.mode:
#     872             # Encoding
# --> 873             handle = open(
#     874                 handle,
#     875                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/Highest Holywood Grossing Movies.csv'

# %%
# Exibe primeiras linhas da base de dados
filmes.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1102/1604845147.py in <cell line: 0>()
#       1 # Exibe primeiras linhas da base de dados
# ----> 2 filmes.head(5)
#
# NameError: name 'filmes' is not defined

# %%
# Mostra informações resumidas da base de dados inicial
filmes.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1102/2774554721.py in <cell line: 0>()
#       1 # Mostra informações resumidas da base de dados inicial
# ----> 2 filmes.info()
#
# NameError: name 'filmes' is not defined

# %%
# Mostra todos os nomes das colunas da base de dados
filmes.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1102/29452525.py in <cell line: 0>()
#       1 # Mostra todos os nomes das colunas da base de dados
# ----> 2 filmes.columns
#
# NameError: name 'filmes' is not defined

# %%
# Renomeia as colunas com nomes em PT-BR
filmes = filmes.rename(columns={
    'Title': 'Titulo',
    'Movie Info': 'Sinopse',
    'Year': 'Ano',
    'Distributor': 'Distribuidora',
    'Budget (in $)': 'Orcamento (US$)',
    'Domestic Opening (in $)': 'Abertura Domestica (US$)',
    'Domestic Sales (in $)': 'Vendas Domesticas (US$)',
    'International Sales (in $)': 'Vendas Internacionais (US$)',
    'World Wide Sales (in $)': 'Vendas Globais (US$)',
    'Release Date': 'Lancamento',
    'Genre': 'Genero',
    'Running Time': 'Duracao',
    'License': 'Licenca'
})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1102/3489177990.py in <cell line: 0>()
#       1 # Renomeia as colunas com nomes em PT-BR
# ----> 2 filmes = filmes.rename(columns={
#       3     'Title': 'Titulo',
#       4     'Movie Info': 'Sinopse',
#       5     'Year': 'Ano',
#
# NameError: name 'filmes' is not defined

# %%
# Remove coluna 'Unnamed: 0' (elimina repetição da ordem numérica das linhas)
filmes = filmes.drop(columns=['Unnamed: 0'])

# Converte coluna 'Lancamento' para o formato datetime64 (data numérica)
filmes['Lancamento'] = pd.to_datetime(filmes['Lancamento'], format='%d-%b-%y')

# Formata a coluna de data para 'dia-mes-ano'
filmes['Lancamento'] = filmes['Lancamento'].dt.strftime('%d-%m-%Y')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1102/1389504209.py in <cell line: 0>()
#       1 # Remove coluna 'Unnamed: 0' (elimina repetição da ordem numérica das linhas)
# ----> 2 filmes = filmes.drop(columns=['Unnamed: 0'])
#       3
#       4 # Converte coluna 'Lancamento' para o formato datetime64 (data numérica)
#       5 filmes['Lancamento'] = pd.to_datetime(filmes['Lancamento'], format='%d-%b-%y')
#
# NameError: name 'filmes' is not defined

# %%
# Salva o novo dataset
filmes.to_csv('filmes_modificado.csv', index=False)

print("Dataset modificado, datas convertidas, e foi salvo com sucesso!")

# Exibe primeiras linhas da base de dados modificada
filmes.head(5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1102/3600907520.py in <cell line: 0>()
#       1 # Salva o novo dataset
# ----> 2 filmes.to_csv('filmes_modificado.csv', index=False)
#       3
#       4 print("Dataset modificado, datas convertidas, e foi salvo com sucesso!")
#       5
#
# NameError: name 'filmes' is not defined

# %% [markdown]
# # PARTE II

# %% [markdown]
# > ### CONSULTAS SQL NA BASE DE DADOS MODIFICADA

# %%
# Conectar ao banco de dados SQLite
connect = sqlite3.connect(':memory:')
filmes.to_sql('filmes', connect, index=False, if_exists='replace')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1102/2308782499.py in <cell line: 0>()
#       1 # Conectar ao banco de dados SQLite
#       2 connect = sqlite3.connect(':memory:')
# ----> 3 filmes.to_sql('filmes', connect, index=False, if_exists='replace')
#
# NameError: name 'filmes' is not defined

# %% [markdown]
# ###### 1. Obtenha apenas os títulos dos filmes e seus orçamentos.

# %%
# Selecionar colunas específicas
query = "SELECT Titulo, `Orcamento (US$)` FROM filmes;"
results = pd.read_sql_query(query, connect)
results
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: filmes
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_1102/704776593.py in <cell line: 0>()
#       1 # Selecionar colunas específicas
#       2 query = "SELECT Titulo, `Orcamento (US$)` FROM filmes;"
# ----> 3 results = pd.read_sql_query(query, connect)
#       4 results
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT Titulo, `Orcamento (US$)` FROM filmes;': no such table: filmes

# %% [markdown]
# ###### 2. Liste todos os filmes lançados após o ano 2000, mostrando o título e o ano de lançamento.

# %%
# Filtrar resultados
query = "SELECT Titulo, Ano FROM filmes WHERE Ano > 2000;"
results = pd.read_sql_query(query, connect)
results
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: filmes
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_1102/3831593301.py in <cell line: 0>()
#       1 # Filtrar resultados
#       2 query = "SELECT Titulo, Ano FROM filmes WHERE Ano > 2000;"
# ----> 3 results = pd.read_sql_query(query, connect)
#       4 results
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT Titulo, Ano FROM filmes WHERE Ano > 2000;': no such table: filmes

# %% [markdown]
# ###### 3. Liste os títulos dos filmes ordenados pelas vendas globais em ordem crescente, mostrando os valores.

# %%
# Ordenar resultados
query = "SELECT Titulo, `Vendas Globais (US$)` FROM filmes ORDER BY `Vendas Globais (US$)`;"
results = pd.read_sql_query(query, connect)
results
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: filmes
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_1102/3925249545.py in <cell line: 0>()
#       1 # Ordenar resultados
#       2 query = "SELECT Titulo, `Vendas Globais (US$)` FROM filmes ORDER BY `Vendas Globais (US$)`;"
# ----> 3 results = pd.read_sql_query(query, connect)
#       4 results
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT Titulo, `Vendas Globais (US$)` FROM filmes ORDER BY `Vendas Globais (US$)`;': no such table: filmes

# %% [markdown]
# ###### 4. Conte quantos filmes da distribuidora "Walt Disney Studios Motion Pictures" existem na base de dados.

# %%
# Contar registros
query = "SELECT COUNT(*) FROM filmes WHERE Distribuidora = 'Walt Disney Studios Motion Pictures';"
results = pd.read_sql_query(query, connect)
print("A distribuidora Walt Disney Studios Motion Pictures possui", results.iloc[0, 0], "filmes.")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: filmes
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_1102/4252400333.py in <cell line: 0>()
#       1 # Contar registros
#       2 query = "SELECT COUNT(*) FROM filmes WHERE Distribuidora = 'Walt Disney Studios Motion Pictures';"
# ----> 3 results = pd.read_sql_query(query, connect)
#       4 print("A distribuidora Walt Disney Studios Motion Pictures possui", results.iloc[0, 0], "filmes.")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT COUNT(*) FROM filmes WHERE Distribuidora = 'Walt Disney Studios Motion Pictures';': no such table: filmes

# %% [markdown]
# ###### 5. Calcule a média de vendas globais dos filmes lançados entre 1990 e 2000.

# %%
# Usar funções de agregação
query = "SELECT AVG(`Vendas Globais (US$)`) FROM filmes WHERE Ano BETWEEN 1990 AND 2000;"
results = pd.read_sql_query(query, connect)
media_vendas = format(results.iloc[0, 0], ',.2f')
print(f"A média de vendas dos filmes entre 1990 e 2000 é de US$ {media_vendas}")
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: filmes
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_1102/1536119155.py in <cell line: 0>()
#       1 # Usar funções de agregação
#       2 query = "SELECT AVG(`Vendas Globais (US$)`) FROM filmes WHERE Ano BETWEEN 1990 AND 2000;"
# ----> 3 results = pd.read_sql_query(query, connect)
#       4 media_vendas = format(results.iloc[0, 0], ',.2f')
#       5 print(f"A média de vendas dos filmes entre 1990 e 2000 é de US$ {media_vendas}")
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT AVG(`Vendas Globais (US$)`) FROM filmes WHERE Ano BETWEEN 1990 AND 2000;': no such table: filmes

# %% [markdown]
# ######  6. Calcule o total de vendas globais de filmes por distribuidora.

# %%
# Agrupar resultados
query = "SELECT Distribuidora, SUM(`Vendas Globais (US$)`) AS Total_Vendas FROM filmes GROUP BY Distribuidora;"
results = pd.read_sql_query(query, connect)
results
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: filmes
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_1102/548092505.py in <cell line: 0>()
#       1 # Agrupar resultados
#       2 query = "SELECT Distribuidora, SUM(`Vendas Globais (US$)`) AS Total_Vendas FROM filmes GROUP BY Distribuidora;"
# ----> 3 results = pd.read_sql_query(query, connect)
#       4 results
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT Distribuidora, SUM(`Vendas Globais (US$)`) AS Total_Vendas FROM filmes GROUP BY Distribuidora;': no such table: filmes

# %% [markdown]
# ###### 7. Liste as distribuidoras que têm mais de 50 filmes.

# %%
# Filtrar Dados Agrupados com cláusula HAVING
query = "SELECT Distribuidora, COUNT(*) AS Total_Filmes FROM filmes GROUP BY Distribuidora HAVING Total_Filmes > 50;"
results = pd.read_sql_query(query, connect)
results
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: filmes
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_1102/2782183744.py in <cell line: 0>()
#       1 # Filtrar Dados Agrupados com cláusula HAVING
#       2 query = "SELECT Distribuidora, COUNT(*) AS Total_Filmes FROM filmes GROUP BY Distribuidora HAVING Total_Filmes > 50;"
# ----> 3 results = pd.read_sql_query(query, connect)
#       4 results
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT Distribuidora, COUNT(*) AS Total_Filmes FROM filmes GROUP BY Distribuidora HAVING Total_Filmes > 50;': no such table: filmes

# %% [markdown]
# ###### 8. Selecionar os filmes com maior venda doméstica e maior venda global, mostrando os valores.

# %%
# Selecionar o filme com maior venda doméstica
query = "SELECT Titulo, `Vendas Domesticas (US$)` FROM filmes WHERE `Vendas Domesticas (US$)` = (SELECT MAX(`Vendas Domesticas (US$)`) FROM filmes);"
results = pd.read_sql_query(query, connect)

# Formatar o valor das vendas com separadores de milhares
vendas_formatadas = format(results.iloc[0, 1], ',.2f')
print("O filme com maior venda doméstica é:", results.iloc[0, 0], "com US$", vendas_formatadas)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: filmes
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_1102/4080945227.py in <cell line: 0>()
#       1 # Selecionar o filme com maior venda doméstica
#       2 query = "SELECT Titulo, `Vendas Domesticas (US$)` FROM filmes WHERE `Vendas Domesticas (US$)` = (SELECT MAX(`Vendas Domesticas (US$)`) FROM filmes);"
# ----> 3 results = pd.read_sql_query(query, connect)
#       4
#       5 # Formatar o valor das vendas com separadores de milhares
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT Titulo, `Vendas Domesticas (US$)` FROM filmes WHERE `Vendas Domesticas (US$)` = (SELECT MAX(`Vendas Domesticas (US$)`) FROM filmes);': no such table: filmes

# %%
# Selecionar o filme com maior venda global
query = "SELECT Titulo, `Vendas Globais (US$)` FROM filmes WHERE `Vendas Globais (US$)` = (SELECT MAX(`Vendas Globais (US$)`) FROM filmes);"
results = pd.read_sql_query(query, connect)

# Formatar o valor das vendas com separadores de milhares
vendas_formatadas = format(results.iloc[0, 1], ',.2f')
print("O filme com maior venda global é:", results.iloc[0, 0], "com US$", vendas_formatadas)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2673         try:
# -> 2674             cur.execute(sql, *args)
#    2675             return cur
#
# OperationalError: no such table: filmes
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# /tmp/ipykernel_1102/43243996.py in <cell line: 0>()
#       1 # Selecionar o filme com maior venda global
#       2 query = "SELECT Titulo, `Vendas Globais (US$)` FROM filmes WHERE `Vendas Globais (US$)` = (SELECT MAX(`Vendas Globais (US$)`) FROM filmes);"
# ----> 3 results = pd.read_sql_query(query, connect)
#       4
#       5 # Formatar o valor das vendas com separadores de milhares
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize, dtype, dtype_backend)
#     524
#     525     with pandasSQL_builder(con) as pandas_sql:
# --> 526         return pandas_sql.read_query(
#     527             sql,
#     528             index_col=index_col,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2736         dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2737     ) -> DataFrame | Iterator[DataFrame]:
# -> 2738         cursor = self.execute(sql, params)
#    2739         columns = [col_desc[0] for col_desc in cursor.description]
#    2740
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/sql.py in execute(self, sql, params)
#    2684
#    2685             ex = DatabaseError(f"Execution failed on sql '{sql}': {exc}")
# -> 2686             raise ex from exc
#    2687
#    2688     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT Titulo, `Vendas Globais (US$)` FROM filmes WHERE `Vendas Globais (US$)` = (SELECT MAX(`Vendas Globais (US$)`) FROM filmes);': no such table: filmes

# %% [markdown]
# ###### Parabéns por chegar ao final deste notebook. Aproveite para salvar uma cópia no seu Google Drive (no menu superior, clicando em Arquivo/Salvar uma cópia no Drive). Bons estudos! 🤩
